# %%
from glob import glob
from tqdm import tqdm
import librosa
import pandas as pd
import numpy as np

# %%
pd.read_csv('datasets\\immint0\\metadata.csv', sep = '|', header = None)
# Out:
#                         0                                      1
# 0    u_5g6p_jvpg.0000.wav                                    예 아
# 1    u_5g6p_jvpg.0001.wav                                3 4 5 아
# 2    u_5g6p_jvpg.0002.wav                          달달하고 따뜻한 다 되요
# 3    u_5g6p_jvpg.0003.wav                                      5
# 4    u_5g6p_jvpg.0004.wav                        탈라 라바 은 다섯번째 여행
# ..                    ...                                    ...
# 916  u_5g6p_jvpg.0916.wav                                      5
# 917  u_5g6p_jvpg.0917.wav                 마치 많군요 2019년 인기 드라마 였죠
# 918  u_5g6p_jvpg.0918.wav  드라마 동백꽃 필 우리야 ost 폰트의 영화 속에 나오는 주인공처럼
# 919  u_5g6p_jvpg.0919.wav                                 들려드릴게요
# 920  u_5g6p_jvpg.0920.wav                            단을 좋은 꿈 꾸세요
#
# [921 rows x 2 columns]

# %%
glob('C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\*.wav')
# Out:
# ['C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\u_5g6p_jvpg.0000.wav',
#  'C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\u_5g6p_jvpg.0001.wav',
#  'C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\u_5g6p_jvpg.0002.wav',
#  'C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\u_5g6p_jvpg.0003.wav',
#  'C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\u_5g6p_jvpg.0004.wav',
#  'C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\u_5g6p_jvpg.0005.wav',
#  'C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\u_5g6p_jvpg.0006.wav',
#  'C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\u_5g6p_jvpg.0007.wav',
#  'C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\u_5g6p_jvpg.0008.wav',
#  'C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\u_5g6p_jvpg.0009.wav',
#  'C:\\Users\\jungs\\Desktop\\TTS\\datasets\\immint0\\wavs\\u_5g6p_jvpg.0010.wav',
# ...
